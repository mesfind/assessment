# %%
# Import all the things

import pandas as pd
# import seaborn as sns
import matplotlib.pyplot as plt

from ipywidgets import interactive
from IPython.display import display
import ipywidgets as widgets
from ipywidgets import interact, widgets


# %matplotlib inline

# %%
# Read in data

workshops  = pd.read_csv('workshops.csv')

# %% [markdown]
# ## Preview the whole dataframe

# %%
# Preview data

workshops
# Out:
#                                    slug    tag_name    yr  attendance  \
# 0                    2011-11-07-toronto         SWC  2011        22.0
# 1                      2012-01-18-stsci         SWC  2012        14.0
# 2                       2012-02-20-itcp         SWC  2012        50.0
# 3                    2012-02-23-toronto         SWC  2012        28.0
# 4                    2012-03-07-indiana         SWC  2012        39.0
# 5                      2012-03-26-mbari         SWC  2012        38.0
# 6                      2012-03-28-nersc         SWC  2012        35.0
# 7                    2012-04-02-chicago         SWC  2012        35.0
# 8                  2012-04-14-utahstate         SWC  2012        32.0
# 9                        2012-04-30-ucl         SWC  2012        44.0
# 10             2012-05-07-michiganstate         SWC  2012        55.0
# 11                 2012-05-14-newcastle         SWC  2012        41.0
# 12                   2012-05-16-alberta         SWC  2012        38.0
# 13                       2012-05-22-ubc         SWC  2012        39.0
# 14                       2012-06-18-jhu         SWC  2012        20.0
# 15                     2012-06-28-inria         SWC  2012        28.0
# 16                       2012-07-09-mit         SWC  2012        36.0
# 17                       2012-07-10-ral         SWC  2012        24.0
# 18                  2012-07-12-waterloo         SWC  2012        40.0
# 19                   2012-07-16-halifax         SWC  2012        40.0
# 20                      2012-07-19-utsc         SWC  2012        39.0
# 21                2012-08-26-ttt-online  TTT,online  2012        20.0
# 22                      2012-09-13-dafx         SWC  2012        33.0
# 23                      2012-09-17-oslo         SWC  2012        34.0
# 24                  2012-09-28-columbia         SWC  2012        39.0
# 25                    2012-10-08-purdue         SWC  2012        42.0
# 26                2012-10-11-ttt-online  TTT,online  2012        25.0
# 27                       2012-10-17-lbl         SWC  2012        40.0
# 28                       2012-10-18-ubc         SWC  2012        62.0
# 29                       2012-10-20-ucb         SWC  2012        29.0
# ...                                 ...         ...   ...         ...
# 1353                   2017-11-30-MBARI         SWC  2017        44.0
# 1354                  2017-11-30-NWU-IT         SWC  2017        16.0
# 1355               2017-11-30-minnesota         SWC  2017        18.0
# 1356                 2017-11-30-queensu         SWC  2017        25.0
# 1357              2017-12-01-gwu-Python         SWC  2017        15.0
# 1358             2017-12-02-UCSF-Python         SWC  2017        24.0
# 1359                  2017-12-02-UCSF-R         SWC  2017        34.0
# 1360                     2017-12-02-mun         SWC  2017        33.0
# 1361               2017-12-04-standrews         SWC  2017        17.0
# 1362                     2017-12-04-ttt  TTT,online  2017         8.0
# 1363                 2017-12-05-rutgers          DC  2017        34.0
# 1364         2017-12-05-ttt-southampton         TTT  2017        18.0
# 1365                2017-12-07-Monsanto         SWC  2017         NaN
# 1366                2017-12-11-Imperial         SWC  2017        26.0
# 1367                   2017-12-12-MQU-R         SWC  2017        34.0
# 1368                  2017-12-12-acadia         SWC  2017        23.0
# 1369              2017-12-12-ttt-online  TTT,online  2017        16.0
# 1370               2017-12-13-amsterdam          DC  2017        11.0
# 1371          2017-12-14-MAN-SS-PILOT01          DC  2017         NaN
# 1372  2017-12-14-UCL_software_carpentry         SWC  2017         NaN
# 1373                2017-12-14-mcmaster          DC  2017        27.0
# 1374                2017-12-14-ttt-uiuc         TTT  2017        10.0
# 1375                     2017-12-14-ucr          LC  2017         9.0
# 1376                    2017-12-18-PNNL         SWC  2017         NaN
# 1377            2017-12-18-grand-valley          DC  2017        19.0
# 1378               2017-12-18-knoxville         SWC  2017        31.0
# 1379                     2017-12-18-osu         SWC  2017         NaN
# 1380                   2017-12-18-umich         SWC  2017        15.0
# 1381              2017-12-20-normandale         SWC  2017        19.0
# 1382     datacarpentry_2015-11-23_VLSCI          DC  2015        18.0
#
#                                           fullname  administrator_id
# 0                            University of Toronto             297.0
# 1                Space Telescope Science Institute             173.0
# 2     International Centre for Theoretical Physics             306.0
# 3                            University of Toronto             297.0
# 4                               Indiana University             173.0
# 5         Monterey Bay Aquarium Research Institute             173.0
# 6                                            NERSC             173.0
# 7                            University of Chicago             173.0
# 8                            Utah State University             173.0
# 9                        University College London             278.0
# 10                       Michigan State University             173.0
# 11                         University of Newcastle             278.0
# 12                           University of Alberta             297.0
# 13                  University of British Columbia             297.0
# 14                        Johns Hopkins University             173.0
# 15                                   INRIA (Paris)             306.0
# 16           Massachusetts Institute of Technology             173.0
# 17         Science & Technology Facilities Council             278.0
# 18                          University of Waterloo             297.0
# 19                         Saint Mary's University             297.0
# 20             University of Toronto (Scarborough)             297.0
# 21                              Software Carpentry             173.0
# 22                                 DAFX Conference             278.0
# 23                              University of Oslo             306.0
# 24                             Columbia University             173.0
# 25                               Purdue University             173.0
# 26                              Software Carpentry             173.0
# 27           Lawrence Berkeley National Laboratory             173.0
# 28                  University of British Columbia             297.0
# 29               University of California Berkeley             173.0
# ...                                            ...               ...
# 1353      Monterey Bay Aquarium Research Institute             343.0
# 1354                         North-West University             343.0
# 1355                       University of Minnesota             173.0
# 1356                            Queen's University             297.0
# 1357                  George Washington University             173.0
# 1358        University of California San Francisco             173.0
# 1359        University of California San Francisco             173.0
# 1360                           Memorial University             343.0
# 1361                     University of St. Andrews             278.0
# 1362                            Software Carpentry             173.0
# 1363                            Rutgers University             302.0
# 1364                            Software Carpentry             173.0
# 1365                                      Monsanto             343.0
# 1366                       Imperial College London             343.0
# 1367                          Macquarie University             121.0
# 1368                             Acadia University             343.0
# 1369                            Software Carpentry             173.0
# 1370                       University of Amsterdam             302.0
# 1371                      University of Manchester             343.0
# 1372                     University College London             343.0
# 1373                           McMaster University             297.0
# 1374                            Software Carpentry             173.0
# 1375           University of California, Riverside             343.0
# 1376               Pacific Northwest National Lab              343.0
# 1377                 Grand Valley State University             302.0
# 1378             University of Tennessee Knoxville             343.0
# 1379                     Oklahoma State University             343.0
# 1380                        University of Michigan             343.0
# 1381                       Winona State University             173.0
# 1382                                         VLSCI             343.0
#
# [1383 rows x 6 columns]

# %%
def workshops_by_year(data, year): 
    """Takes a dataframe and a year, returns dataframe filtered by year"""
    df = pd.read_csv(data)
    df = df[df['yr'] == year]
    return df

# %% [markdown]
# ## Select a year to see a dataframe of all workshops (across Carpentries) that year

# %%
# The interact function takes as arguments the function and that function's arguments separately
interact(workshops_by_year, data = 'workshops.csv', year = range(2011, 2018))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-43c2c3327379> in <module>()
#       1 # The interact function takes as arguments the function and that function's arguments separately
# ----> 2 interact(workshops_by_year, data = 'workshops.csv', year = range(2011, 2018))
#
# /home/maneesha/.virtualenvs/surveys/lib/python3.5/site-packages/ipywidgets/widgets/interaction.py in interact(__interact_f, **kwargs)
#     356         #        ...
#     357         f = __interact_f
# --> 358         w = interactive(f, **kwargs)
#     359         try:
#     360             f.widget = w
#
# /home/maneesha/.virtualenvs/surveys/lib/python3.5/site-packages/ipywidgets/widgets/interaction.py in interactive(__interact_f, **kwargs)
#     234         getcallargs(f, **{n:v for n,v,_ in new_kwargs})
#     235     # Now build the widgets from the abbreviations.
# --> 236     kwargs_widgets.extend(_widgets_from_abbreviations(new_kwargs))
#     237
#     238     # This has to be done as an assignment, not using container.children.append,
#
# /home/maneesha/.virtualenvs/surveys/lib/python3.5/site-packages/ipywidgets/widgets/interaction.py in _widgets_from_abbreviations(seq)
#     187     result = []
#     188     for name, abbrev, default in seq:
# --> 189         widget = _widget_from_abbrev(abbrev, default)
#     190         if not widget.description:
#     191             widget.description = name
#
# /home/maneesha/.virtualenvs/surveys/lib/python3.5/site-packages/ipywidgets/widgets/interaction.py in _widget_from_abbrev(abbrev, default)
#     141             pass
#     142     if widget is None:
# --> 143         raise ValueError("%r cannot be transformed to a Widget" % (abbrev,))
#     144     return widget
#     145
#
# ValueError: range(2011, 2018) cannot be transformed to a Widget

# %%
def workshops_by_carpentry(data, carpentry): 
    """Takes a dataframe and a carpentry, returns dataframe filtered by that carpentry"""
    df = pd.read_csv(data)
    df = df[df['tag_name'].str.contains(carpentry)]
    return df

# %% [markdown]
# ## Select a Carpentry to see a dataframe of all workshops for that Carpentry (across all years)

# %%
interact(workshops_by_carpentry, data = 'workshops.csv', carpentry = ['SWC', 'DC', 'LC'])
# Out:
#                                    slug tag_name    yr  attendance  \
# 0                    2011-11-07-toronto      SWC  2011        22.0
# 1                      2012-01-18-stsci      SWC  2012        14.0
# 2                       2012-02-20-itcp      SWC  2012        50.0
# 3                    2012-02-23-toronto      SWC  2012        28.0
# 4                    2012-03-07-indiana      SWC  2012        39.0
# 5                      2012-03-26-mbari      SWC  2012        38.0
# 6                      2012-03-28-nersc      SWC  2012        35.0
# 7                    2012-04-02-chicago      SWC  2012        35.0
# 8                  2012-04-14-utahstate      SWC  2012        32.0
# 9                        2012-04-30-ucl      SWC  2012        44.0
# 10             2012-05-07-michiganstate      SWC  2012        55.0
# 11                 2012-05-14-newcastle      SWC  2012        41.0
# 12                   2012-05-16-alberta      SWC  2012        38.0
# 13                       2012-05-22-ubc      SWC  2012        39.0
# 14                       2012-06-18-jhu      SWC  2012        20.0
# 15                     2012-06-28-inria      SWC  2012        28.0
# 16                       2012-07-09-mit      SWC  2012        36.0
# 17                       2012-07-10-ral      SWC  2012        24.0
# 18                  2012-07-12-waterloo      SWC  2012        40.0
# 19                   2012-07-16-halifax      SWC  2012        40.0
# 20                      2012-07-19-utsc      SWC  2012        39.0
# 22                      2012-09-13-dafx      SWC  2012        33.0
# 23                      2012-09-17-oslo      SWC  2012        34.0
# 24                  2012-09-28-columbia      SWC  2012        39.0
# 25                    2012-10-08-purdue      SWC  2012        42.0
# 27                       2012-10-17-lbl      SWC  2012        40.0
# 28                       2012-10-18-ubc      SWC  2012        62.0
# 29                       2012-10-20-ucb      SWC  2012        29.0
# 30                 2012-10-22-newcastle      SWC  2012        31.0
# 31                   2012-10-23-caltech      SWC  2012        34.0
# ...                                 ...      ...   ...         ...
# 1336                  2017-11-07-mcgill      SWC  2017        17.0
# 1337                  2017-11-07-mizzou      SWC  2017        15.0
# 1339         2017-11-08-southampton-swc      SWC  2017        17.0
# 1340                     2017-11-09-sfn      SWC  2017        26.0
# 1341                  2017-11-09-uclhep      SWC  2017        14.0
# 1342                     2017-11-11-UTA      SWC  2017        12.0
# 1343                2017-11-13-ethiopia      SWC  2017        27.0
# 1347                   2017-11-17-tufts      SWC  2017        14.0
# 1348                      2017-11-20-ou      SWC  2017        20.0
# 1350      2017-11-23-GriffithUni-Python      SWC  2017        24.0
# 1352             2017-11-27-USyd-Python      SWC  2017        12.0
# 1353                   2017-11-30-MBARI      SWC  2017        44.0
# 1354                  2017-11-30-NWU-IT      SWC  2017        16.0
# 1355               2017-11-30-minnesota      SWC  2017        18.0
# 1356                 2017-11-30-queensu      SWC  2017        25.0
# 1357              2017-12-01-gwu-Python      SWC  2017        15.0
# 1358             2017-12-02-UCSF-Python      SWC  2017        24.0
# 1359                  2017-12-02-UCSF-R      SWC  2017        34.0
# 1360                     2017-12-02-mun      SWC  2017        33.0
# 1361               2017-12-04-standrews      SWC  2017        17.0
# 1365                2017-12-07-Monsanto      SWC  2017         NaN
# 1366                2017-12-11-Imperial      SWC  2017        26.0
# 1367                   2017-12-12-MQU-R      SWC  2017        34.0
# 1368                  2017-12-12-acadia      SWC  2017        23.0
# 1372  2017-12-14-UCL_software_carpentry      SWC  2017         NaN
# 1376                    2017-12-18-PNNL      SWC  2017         NaN
# 1378               2017-12-18-knoxville      SWC  2017        31.0
# 1379                     2017-12-18-osu      SWC  2017         NaN
# 1380                   2017-12-18-umich      SWC  2017        15.0
# 1381              2017-12-20-normandale      SWC  2017        19.0
#
#                                           fullname  administrator_id
# 0                            University of Toronto             297.0
# 1                Space Telescope Science Institute             173.0
# 2     International Centre for Theoretical Physics             306.0
# 3                            University of Toronto             297.0
# 4                               Indiana University             173.0
# 5         Monterey Bay Aquarium Research Institute             173.0
# 6                                            NERSC             173.0
# 7                            University of Chicago             173.0
# 8                            Utah State University             173.0
# 9                        University College London             278.0
# 10                       Michigan State University             173.0
# 11                         University of Newcastle             278.0
# 12                           University of Alberta             297.0
# 13                  University of British Columbia             297.0
# 14                        Johns Hopkins University             173.0
# 15                                   INRIA (Paris)             306.0
# 16           Massachusetts Institute of Technology             173.0
# 17         Science & Technology Facilities Council             278.0
# 18                          University of Waterloo             297.0
# 19                         Saint Mary's University             297.0
# 20             University of Toronto (Scarborough)             297.0
# 22                                 DAFX Conference             278.0
# 23                              University of Oslo             306.0
# 24                             Columbia University             173.0
# 25                               Purdue University             173.0
# 27           Lawrence Berkeley National Laboratory             173.0
# 28                  University of British Columbia             297.0
# 29               University of California Berkeley             173.0
# 30                         University of Newcastle             278.0
# 31              California Institute of Technology             173.0
# ...                                            ...               ...
# 1336                             McGill University             297.0
# 1337                        University of Missouri             173.0
# 1339         SSI Software Sustainability Institute             278.0
# 1340                      Society for Neuroscience             173.0
# 1341                     University College London             278.0
# 1342                 University of Texas Arlington             343.0
# 1343                        Addis Ababa University             343.0
# 1347                              Tufts University             343.0
# 1348                        University of Oklahoma             343.0
# 1350                           Griffith University             391.0
# 1352                          University of Sydney             183.0
# 1353      Monterey Bay Aquarium Research Institute             343.0
# 1354                         North-West University             343.0
# 1355                       University of Minnesota             173.0
# 1356                            Queen's University             297.0
# 1357                  George Washington University             173.0
# 1358        University of California San Francisco             173.0
# 1359        University of California San Francisco             173.0
# 1360                           Memorial University             343.0
# 1361                     University of St. Andrews             278.0
# 1365                                      Monsanto             343.0
# 1366                       Imperial College London             343.0
# 1367                          Macquarie University             121.0
# 1368                             Acadia University             343.0
# 1372                     University College London             343.0
# 1376               Pacific Northwest National Lab              343.0
# 1378             University of Tennessee Knoxville             343.0
# 1379                     Oklahoma State University             343.0
# 1380                        University of Michigan             343.0
# 1381                       Winona State University             173.0
#
# [1048 rows x 6 columns]
# <function __main__.workshops_by_carpentry>

# %%
def attendance_by_carpentry_and_year(data, carpentry): 
    """Takes a dataframe and a carpentry, returns attendance total by year for that carpentry as pandas series and bar plot"""
    df = pd.read_csv(data)
    df = df[df['tag_name'].str.contains(carpentry)]
    attendance_by_year = df.groupby('yr')['attendance'].sum()
   
    attendance_list = attendance_by_year.tolist()
    
    offset = max(attendance_list) * .025
    ax = attendance_by_year.plot(x = 'yr', y = 'attendance', kind = 'bar')
    for i in range(len(attendance_list)):
        ax.text(i, attendance_list[i] + offset, str(int(attendance_list[i])))
    plt.show()
    
    return attendance_by_year

# %% [markdown]
# ## Select a Carpentry to see a bar chart of attendance by year for that Carpentry
#
# This does not account for workshops missing attendance

# %%
interact(attendance_by_carpentry_and_year, data = 'workshops.csv', carpentry = ['SWC', 'DC', 'LC'])
# Out:
# yr
# 2011      22.0
# 2012    1378.0
# 2013    3212.0
# 2014    4683.0
# 2015    7047.0
# 2016    5562.0
# 2017    5574.0
# Name: attendance, dtype: float64
# <function __main__.attendance_by_carpentry_and_year>

# %%
def workshops_by_carpentry_and_year(data, carpentry="All", yr="All", stacked = True, agg="workshop count"): 
    """Takes a dataframe and a carpentry, returns dataframe filtered by that carpentry"""
    df = pd.read_csv(data)
    df.loc[df.administrator_id != 343, 'administrator_id'] = 'centrally'
    df.loc[df.administrator_id == 343, 'administrator_id'] = 'self'
    
    df.loc[df["tag_name"].str.contains("SWC"), 'tag_name'] = "SWC"
    df.loc[df["tag_name"].str.contains("DC"), 'tag_name'] = "DC"
    df.loc[df["tag_name"].str.contains("LC"), 'tag_name'] = "LC"
    df.loc[df["tag_name"].str.contains("TTT"), 'tag_name'] = "TTT"

    if carpentry != "All":
        df = df[df['tag_name'].str.contains(carpentry)]
    if yr != "All":
        df = df[df['yr'] == yr]
    
    if agg == "workshop count":
        attendance_by_year = df.groupby(['yr', 'tag_name', 'administrator_id'])['slug'].count()
    elif agg == "attendance sum":
        attendance_by_year = df.groupby(['yr', 'tag_name', 'administrator_id'])['attendance'].sum()

    attendance_by_year = attendance_by_year.to_frame()
    attendance_by_year.unstack().plot(kind='bar', stacked=stacked)

    return attendance_by_year

# %% [markdown]
# ## Seelct a Carpentry and year to see a bar chart of workshop count OR attendance total for that Carpentry/year and that bar chart's source dataframe by self organized and centrally organized workshops.  Select "stacked" to toggle stacked view or side by side view.
#
# This does not account for workshops missing attendance.  See here on how to fill na with means:
# https://chrisalbon.com/python/data_wrangling/pandas_missing_data/
#
# Need to figure out how to make the legends and labels more human readable.

# %%
interact(workshops_by_carpentry_and_year, data = 'workshops.csv', stacked = [True, False], carpentry = ['All', 'SWC', 'DC', 'LC', 'TTT'], yr = ["All"] + list(range(2011, 2019)), agg=["attendance sum", "workshop count"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-101d41af963a> in <module>()
# ----> 1 interact(workshops_by_carpentry_and_year, data = 'workshops.csv', stacked = [True, False], carpentry = ['All', 'SWC', 'DC', 'LC', 'TTT'], yr = ["All"] + list(range(2011, 2019)), agg=["attendance sum", "workshop count"])
#
# /home/maneesha/.virtualenvs/surveys/lib/python3.5/site-packages/ipywidgets/widgets/interaction.py in interact(__interact_f, **kwargs)
#     356         #        ...
#     357         f = __interact_f
# --> 358         w = interactive(f, **kwargs)
#     359         try:
#     360             f.widget = w
#
# /home/maneesha/.virtualenvs/surveys/lib/python3.5/site-packages/ipywidgets/widgets/interaction.py in interactive(__interact_f, **kwargs)
#     234         getcallargs(f, **{n:v for n,v,_ in new_kwargs})
#     235     # Now build the widgets from the abbreviations.
# --> 236     kwargs_widgets.extend(_widgets_from_abbreviations(new_kwargs))
#     237
#     238     # This has to be done as an assignment, not using container.children.append,
#
# /home/maneesha/.virtualenvs/surveys/lib/python3.5/site-packages/ipywidgets/widgets/interaction.py in _widgets_from_abbreviations(seq)
#     187     result = []
#     188     for name, abbrev, default in seq:
# --> 189         widget = _widget_from_abbrev(abbrev, default)
#     190         if not widget.description:
#     191             widget.description = name
#
# /home/maneesha/.virtualenvs/surveys/lib/python3.5/site-packages/ipywidgets/widgets/interaction.py in _widget_from_abbrev(abbrev, default)
#     131         return abbrev
#     132
# --> 133     widget = _widget_abbrev(abbrev)
#     134     if default is not empty and isinstance(abbrev, (list, tuple, dict)):
#     135         # if it's not a single-value abbreviation,
#
# /home/maneesha/.virtualenvs/surveys/lib/python3.5/site-packages/ipywidgets/widgets/interaction.py in _widget_abbrev(o)
#      93         if len(o) in [2, 3] and all(isinstance(x, Real) for x in o):
#      94             warn("For Sliders, use a tuple: %s" % (tuple(o),), DeprecationWarning)
# ---> 95             return _widget_abbrev(tuple(o))
#      96         # --------------------------------------------------------------------
#      97         return Dropdown(options=[unicode_type(k) for k in o])
#
# /home/maneesha/.virtualenvs/surveys/lib/python3.5/site-packages/ipywidgets/widgets/interaction.py in _widget_abbrev(o)
#     106         # --------------------------------------------------------------------
#     107         if _matches(o, (Real, Real)):
# --> 108             min, max, value = _get_min_max_value(o[0], o[1])
#     109             if all(isinstance(_, Integral) for _ in o):
#     110                 cls = IntSlider
#
# /home/maneesha/.virtualenvs/surveys/lib/python3.5/site-packages/ipywidgets/widgets/interaction.py in _get_min_max_value(min, max, value, step)
#      43     if value is None:
#      44         if not max > min:
# ---> 45             raise ValueError('max must be greater than min: (min={0}, max={1})'.format(min, max))
#      46         diff = max - min
#      47         value = min + (diff / 2)
#
# ValueError: max must be greater than min: (min=True, max=False)

# %%
# !jupyter nbconvert workshops.ipynb --to html
# Out:
# [NbConvertApp] Converting notebook workshops.ipynb to html
# [NbConvertApp] Writing 286126 bytes to workshops.html
